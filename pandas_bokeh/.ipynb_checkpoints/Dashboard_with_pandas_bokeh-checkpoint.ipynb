# %% [markdown]
# # Building an Interactive Dashboard using Bokeh and Pandas
# [参考URL](https://www.analyticsvidhya.com/blog/2021/09/building-an-interactive-dashboard-using-bokeh-and-pandas/)
#
# 下図のようなDashboardを作成する．
#
# ![dashboard_architechture](images/dashboard_1.png)

# %%
# !pip install pandas-bokeh/
# Out:
# Collecting pandas-bokeh
#   Downloading pandas_bokeh-0.5.5-py2.py3-none-any.whl (29 kB)
# Collecting bokeh>=2.0
#   Downloading bokeh-2.4.2-py3-none-any.whl (18.5 MB)
#      |████████████████████████████████| 18.5 MB 7.7 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.22.0 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from pandas-bokeh) (1.3.5)
# Requirement already satisfied: typing-extensions>=3.10.0 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from bokeh>=2.0->pandas-bokeh) (3.10.0.0)
# Requirement already satisfied: Jinja2>=2.9 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from bokeh>=2.0->pandas-bokeh) (3.0.1)
# Requirement already satisfied: pillow>=7.1.0 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from bokeh>=2.0->pandas-bokeh) (8.3.1)
# Requirement already satisfied: tornado>=5.1 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from bokeh>=2.0->pandas-bokeh) (6.1)
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
#      |████████████████████████████████| 197 kB 12.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.11.3 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from bokeh>=2.0->pandas-bokeh) (1.21.2)
# Requirement already satisfied: packaging>=16.8 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from bokeh>=2.0->pandas-bokeh) (21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh>=2.0->pandas-bokeh) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from packaging>=16.8->bokeh>=2.0->pandas-bokeh) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from pandas>=0.22.0->pandas-bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from pandas>=0.22.0->pandas-bokeh) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/kozo/miniconda3/envs/py39/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.22.0->pandas-bokeh) (1.16.0)
# Installing collected packages: PyYAML, bokeh, pandas-bokeh
# Successfully installed PyYAML-6.0 bokeh-2.4.2 pandas-bokeh-0.5.5

# %%
import numpy as np
import pandas as pd
import pandas_bokeh

# %%
# Embedding plots in Jupyter notebook
pandas_bokeh.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4364">Loading BokehJS ...</span>
#     </div>

# %%
# for exporting plots as HTML
# pandas_bokeh.output_file('dashboard.html')

# %%
#define the categorical variable
category = ['A','B','C']
#set random seed to make the dataset reproducible
np.random.seed(42)
#create a dataset
df_random = pd.DataFrame({
   'id': np.arange(0, 15),
   'month':np.random.randint(1, 12, 15),
   'sensor_1': np.random.uniform(0, 1,15),
   'sensor_2': np.random.uniform(10, 15, 15),
   'sensor_3': np.random.randint(0, 20, 15),
   'category': np.random.choice(category, 15, p=[0.2, 0.4, 0.4])
})

# %%
#set index to id column
df_random=df_random.set_index('id')

# %%
df_random.shape
# Out:
# (15, 5)

# %%
df_random.head()
# Out:
#     month  sensor_1   sensor_2  sensor_3 category
# id
# 0       7  0.708073  12.280350        14        B
# 1       4  0.020584  13.925880         6        A
# 2      11  0.969910  10.998369        11        C
# 3       8  0.832443  12.571172         7        B
# 4       5  0.212339  12.962073        14        B

# %%
colors = ['yellow','pink','green']

# Plot1 - Line plot
p_line= df_random.groupby(['month']).mean().plot_bokeh(kind="line",y="sensor_2",color='#d01c8b',plot_data_points=True,show_figure=False)
# Plot2- Barplot
p_bar = df_random.groupby(['month']).mean().plot_bokeh(kind="bar",colormap=colors,show_figure=False)
# Plot3- stacked bar chart
df_sensor=df_random.drop(['month'],axis=1)
p_stack=df_sensor.groupby(['category']).mean().plot_bokeh(kind='barh', stacked=True,colormap=colors,show_figure=False)
#Plot4- Scatterplot
p_scatter = df_random.plot_bokeh(kind="scatter", x="month", y="sensor_2",category="category",colormap=colors, show_figure=False)
#Plot5- Pie chart
p_pie= df_random.groupby(['category']).mean().plot_bokeh.pie(y='sensor_1',colormap=colors,show_figure=False)
#Plot6- Histogram
p_hist=df_sensor.plot_bokeh(kind='hist', histogram_type="stacked",bins=6,colormap=colors, show_figure=False)
# Out:
# __x__values_original

# %%
#Make Dashboard with Grid Layout: 
pandas_bokeh.plot_grid([[p_line, p_bar,p_stack],[p_scatter, p_pie,p_hist]], width=400)
# Out:
#   <div class="bk-root" id="54dcf1d3-9919-43a1-a772-bc9883c3fd52" data-root-id="4898"></div>
# Column(id='4898', ...)
